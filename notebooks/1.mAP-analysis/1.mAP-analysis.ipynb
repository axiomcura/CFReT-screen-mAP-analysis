# %%
import sys
import pathlib


# adding src module
sys.path.append("../../")

# %% [markdown]
# Setting up paths and creating directories

# %%
# creating directories
figures_dir = pathlib.Path("figures").resolve()
figures_dir.mkdir(exist_ok=True)
results_dir = pathlib.Path("results").resolve()
results_dir.mkdir(exist_ok=True)

# data path 
metadata_paths = None # pathlib.Path("../0.download_data/data/Name_of_metadat").resolve(strict=True)
profile_path = None # pathlib.Path("../0.download_data/data/Name_of_profile").resolve(strict=True)

# config path
config_path = pathlib.Path("config.yaml").resolve(strict=True)

# %% [markdown]
# ## Preparing our dataset

# %%
# loading in config file
